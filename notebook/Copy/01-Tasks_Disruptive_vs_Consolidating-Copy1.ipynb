# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import time
import scipy.sparse
import re

# %% [markdown]
# ## Classification Patents and Their Impacted Tasks

# %% [markdown]
# ### Loading data

# %%
ai_patents = pd.read_csv('../data/processed/ai_patents_keywrods_alicpc_07092024.csv')

# %%
task_ratings = pd.read_csv('../data/raw/db_24_3_text/Task Ratings.txt', sep='\t').query('`Scale ID` == "IM"')
task_statements = pd.read_csv('../data/raw/db_24_3_text/Task Statements.txt', sep='\t')
jobs = pd.read_csv('../data/raw/db_24_3_text/Occupation Data.txt', sep='\t')
jobs['SOC Code'] = jobs['O*NET-SOC Code'].str[:7]
tasks = pd.merge(
    task_ratings,
    task_statements[['O*NET-SOC Code', 'Task ID', 'Task']],
    how='left',
    on=['O*NET-SOC Code', 'Task ID']
)

# %%
tasks = pd.merge(
    task_ratings,
    task_statements[['O*NET-SOC Code', 'Task ID', 'Task']],
    how='left',
    on=['O*NET-SOC Code', 'Task ID']
)

# %%
patent_matched_ids = np.load('../data/processed/Embeddings/ai_patents_matched_id.npy')
cosine_similarity = np.load('../data/processed/Embeddings/ai_related_patents_cosine_similarity_task.npy')

# %%
tasks['patents_cosine_similarity'] = cosine_similarity
tasks['ai_patents_matched_id'] =patent_matched_ids

# %%
ai_patent_both_methods_embedding_id_patent_id_dict = ai_patents.groupby('embedding_id')['patent_id'].apply(list).to_dict()

# %%
ai_embedding_id = list(ai_patents['embedding_id'])

# %%
ai_embedding_id_iloc_id = {iloc_id:i for iloc_id, i in enumerate(ai_embedding_id)}

# %%
tasks['patent_id'] = tasks['ai_patents_matched_id'].apply(lambda x: ai_patent_both_methods_embedding_id_patent_id_dict[ai_embedding_id_iloc_id[x]][0])

# %%
tasks = tasks.merge(ai_patents[['patent_id', 'type', 'number', 'country', 'date', 'year', 'abstract','title', 'kind','paper_id','citations', 'references',
       'disruption', 'edm_disruption' ]], on ='patent_id')

# %% [markdown]
# ## Impacted vs Not Impacted Patents

# %%
quantile_threshold = tasks['patents_cosine_similarity'].quantile(0.9)

# %%
quantile_threshold
# Out:
# 0.7984446704387664

# %%
tasks_notexposedai = tasks[tasks['patents_cosine_similarity']<quantile_threshold]
tasks_exposedai= tasks[tasks['patents_cosine_similarity']>quantile_threshold]

# %% [markdown]
# ## Disruptive AI

# %%
disruptive_threshold = ai_patents['disruption'].quantile(0.75)
consolidating_threshold = ai_patents['disruption'].quantile(0.25)

# %%
ai_patents[ai_patents['disruption']<consolidating_threshold]
# Out:
#       Unnamed: 0 patent_id     type    number country        date  year  \
# 1           3654  10003688  utility  10003688      US  2018-06-19  2018
# 4           7195  10007263  utility  10007263      US  2018-06-26  2018
# 6           9160  10009240  utility  10009240      US  2018-06-26  2018
# 15         19476  10019631  utility  10019631      US  2018-07-10  2018
# 17         19512  10019667  utility  10019667      US  2018-07-10  2018
# ...          ...       ...      ...       ...     ...         ...   ...
# 3228     6680491   9987747  utility   9987747      US  2018-06-05  2018
# 3229     6681364   9988624  utility   9988624      US  2018-06-05  2018
# 3231     6686030   9993313  utility   9993313      US  2018-06-12  2018
# 3235     6692150   9999476  utility   9999476      US  2018-06-19  2018
# 3236     7385497   RE46465  reissue   RE46465      US  2017-07-04  2017
#
#                                                abstract  \
# 1     Systems for caller identification and authenti...
# 4     Methods and systems for monitoring use, determ...
# 6     A method provides for associating reputation s...
# 15    A method of tracking a position of a target ob...
# 17    Embodiments of the present invention provide a...
# ...                                                 ...
# 3228  Disclosed is a stocker for receiving a cassett...
# 3229  The present disclosure provides a HTP microbia...
# 3231  An instrument device manipulator IDM is attach...
# 3235  Robotic and/or surgical devices, systems, and ...
# 3236  A wafer transfer apparatus is provided. In a m...
#
#                                                   title kind  ...  \
# 1     Systems and methods for cluster-based voice ve...   B1  ...
# 4     Autonomous vehicle accident and emergency resp...   B1  ...
# 6     System and method of recommending policies tha...   B2  ...
# 15    Adapting to appearance variations when trackin...   B2  ...
# 17           Transform for a neurosynaptic core circuit   B2  ...
# ...                                                 ...  ...  ...
# 3228  Stocker for receiving cassettes and method of ...   B2  ...
# 3229  Microbial strain improvement by a HTP genomic ...   B2  ...
# 3231  Instrument device manipulator with roll mechanism   B2  ...
# 3235  Movable surgical mounting platform controlled ...   B2  ...
# 3236  Wafer transfer apparatus and substrate transfe...   E1  ...
#
#       cpc_current_group_average_patent_processing_days  term_extension  \
# 1                                                456.0             NaN
# 4                                                963.0           127.0
# 6                                                867.0           231.0
# 15                                               769.0            40.0
# 17                                              1010.0           187.0
# ...                                                ...             ...
# 3228                                             850.0            46.0
# 3229                                             878.0             NaN
# 3231                                             936.0             NaN
# 3235                                             936.0           113.0
# 3236                                               NaN             NaN
#
#      detail_desc_length  paper_id    frac_year disruption edm_disruption  \
# 1               30155.0      3654  2018.416667  -0.003891       0.698857
# 4              152850.0      7195  2018.416667  -0.004117       0.905069
# 6               92346.0      9160  2018.416667  -0.004407       0.850494
# 15              60499.0     19476  2018.500000  -0.010000       0.774313
# 17              25348.0     19512  2018.500000  -0.015873       0.756898
# ...                 ...       ...          ...        ...            ...
# 3228            16153.0   6680491  2018.416667  -0.019858       1.303688
# 3229           354323.0   6681364  2018.416667  -0.014766       0.915063
# 3231            68269.0   6686030  2018.416667  -0.008458       0.826395
# 3235            57177.0   6692150  2018.416667  -0.003115       0.788385
# 3236            75806.0   7385497  2017.500000  -0.065217       0.706346
#
#      citations  references  embedding_id
# 1          4.0        63.0          3654
# 4         21.0       108.0          7195
# 6         22.0       151.0          9160
# 15         3.0         5.0         19476
# 17         3.0        23.0         19512
# ...        ...         ...           ...
# 3228      14.0        26.0       6679684
# 3229      36.0        34.0       6680557
# 3231      40.0        50.0       6685223
# 3235       3.0         5.0       6691343
# 3236       3.0         2.0       6738780
#
# [809 rows x 47 columns]

# %%
disruptive_tasks = tasks_exposedai[(tasks_exposedai['disruption']>disruptive_threshold) ]

# %%
disruptive_tasks
# Out:
#       O*NET-SOC Code  Task ID Scale ID  Category  Data Value    N  \
# 224       11-3051.00       34       IM       NaN        4.24  115
# 231       11-3051.00       33       IM       NaN        3.95   98
# 386       11-3071.02    19512       IM       NaN        3.95   21
# 387       11-3071.02     3310       IM       NaN        3.95   20
# 404       11-3071.02    19511       IM       NaN        3.38   16
# ...              ...      ...      ...       ...         ...  ...
# 19309     53-7033.00    15191       IM       NaN        4.15   59
# 19335     53-7051.00     3201       IM       NaN        4.35  120
# 19338     53-7051.00     3209       IM       NaN        3.62   46
# 19361     53-7062.00    10781       IM       NaN        4.73   83
# 19375     53-7062.00    10787       IM       NaN        3.23   29
#
#        Standard Error  Lower CI Bound  Upper CI Bound Recommend Suppress  ...  \
# 224              0.09            4.05            4.42                  N  ...
# 231              0.10            3.76            4.14                  N  ...
# 386               NaN             NaN             NaN                NaN  ...
# 387               NaN             NaN             NaN                NaN  ...
# 404               NaN             NaN             NaN                NaN  ...
# ...               ...             ...             ...                ...  ...
# 19309            0.23            3.68            4.62                  N  ...
# 19335            0.19            3.98            4.72                  N  ...
# 19338            0.45            2.72            4.52                  N  ...
# 19361            0.09            4.55            4.91                  N  ...
# 19375            0.16            2.91            3.55                  N  ...
#
#              date  year                                           abstract  \
# 224    2016-01-05  2016  In accordance with aspects of the disclosure, ...
# 231    2016-01-05  2016  In accordance with aspects of the disclosure, ...
# 386    2016-11-29  2016  Systems and methods for optimal planning and r...
# 387    2017-04-11  2017  In one embodiment, a method includes determini...
# 404    2016-11-29  2016  Systems and methods for optimal planning and r...
# ...           ...   ...                                                ...
# 19309  2016-10-04  2016  A multi-vehicle type co-production line flexib...
# 19335  2015-03-03  2015  In an infrastructure that uses a mobile order ...
# 19338  2018-03-13  2018  A vehicle trailer connect system and automated...
# 19361  2015-03-03  2015  In an infrastructure that uses a mobile order ...
# 19375  2015-04-07  2015  Disclosed are various embodiments that may fac...
#
#                                                    title  kind paper_id  \
# 224    Capacity expansion planning with production re...    B2  5927992
# 231    Capacity expansion planning with production re...    B2  5927992
# 386                  Energy storage modeling and control    B2  6205172
# 387    Systems and methods for individualized routing...    B1  6315061
# 404                  Energy storage modeling and control    B2  6205172
# ...                                                  ...   ...      ...
# 19309  Multi-vehicle model collinear flexible framing...    B2  6154177
# 19335  Inter-facility transport in inventory manageme...    B1  5671498
# 19338                     Vehicle trailer connect system    B2  6607572
# 19361  Inter-facility transport in inventory manageme...    B1  5671498
# 19375          Item retrieval using a robotic drive unit    B1  5701746
#
#       citations references disruption edm_disruption
# 224         3.0        1.0   0.230769       0.981282
# 231         3.0        1.0   0.230769       0.981282
# 386         9.0        2.0   0.136364       0.729405
# 387         9.0        2.0   0.060870       0.894448
# 404         9.0        2.0   0.136364       0.729405
# ...         ...        ...        ...            ...
# 19309       6.0        7.0   0.046875       1.374008
# 19335      84.0        2.0   0.540984       0.882959
# 19338      22.0        3.0   0.052885       0.987450
# 19361      84.0        2.0   0.540984       0.882959
# 19375      32.0        1.0   0.666667       0.875687
#
# [397 rows x 29 columns]

# %%
consolidating_tasks = tasks_exposedai[(tasks_exposedai['disruption']<consolidating_threshold) ]

# %%
consolidating_tasks
# Out:
#       O*NET-SOC Code  Task ID Scale ID  Category  Data Value   N  \
# 288       11-3051.03    15461       IM       NaN        4.22  58
# 291       11-3051.03    15451       IM       NaN        3.98  56
# 352       11-3071.01     1037       IM       NaN        4.26  71
# 385       11-3071.02    20941       IM       NaN        4.00  22
# 410       11-3071.03    15752       IM       NaN        4.13  30
# ...              ...      ...      ...       ...         ...  ..
# 19450     53-7081.00     7176       IM       NaN        4.77  44
# 19464     53-7081.00     7182       IM       NaN        3.79  23
# 19487     53-7121.00    12798       IM       NaN        4.24  63
# 19496     53-7121.00    12805       IM       NaN        3.87  31
# 19497     53-7121.00    12810       IM       NaN        3.53  36
#
#        Standard Error  Lower CI Bound  Upper CI Bound Recommend Suppress  ...  \
# 288              0.12            3.97            4.46                  N  ...
# 291              0.14            3.70            4.27                  N  ...
# 352              0.11            4.04            4.48                  N  ...
# 385               NaN             NaN             NaN                NaN  ...
# 410               NaN             NaN             NaN                NaN  ...
# ...               ...             ...             ...                ...  ...
# 19450            0.11            4.55            4.98                  N  ...
# 19464            0.28            3.21            4.37                  N  ...
# 19487            0.12            4.00            4.48                  N  ...
# 19496            0.26            3.34            4.41                  N  ...
# 19497            0.25            3.02            4.04                  N  ...
#
#              date  year                                           abstract  \
# 288    2016-02-02  2016  Cooling control methods include measuring a te...
# 291    2017-03-28  2017  Techniques for providing an entity monitoring ...
# 352    2016-10-11  2016  A computer-implemented method for automated se...
# 385    2019-04-23  2019  An example method is carried out in a warehous...
# 410    2017-08-15  2017  Example systems and methods may provide for a ...
# ...           ...   ...                                                ...
# 19450  2017-04-18  2017  An autonomous device for loading and unloading...
# 19464  2017-04-18  2017  An autonomous device for loading and unloading...
# 19487  2017-04-18  2017  An autonomous device for loading and unloading...
# 19496  2016-11-01  2016  A material handling system comprises a main co...
# 19497  2019-04-23  2019  An example method is carried out in a warehous...
#
#                                                    title  kind paper_id  \
# 288    Coolant and ambient temperature control for ch...    B2  5948314
# 291            Entity monitoring for kiva robotic floors    B1  6302663
# 352                         Automated service management    B2  6162424
# 385                   Collaborative inventory monitoring    B2   263891
# 410    Heterogeneous fleet of robots for collaborativ...    B1  6428105
# ...                                                  ...   ...      ...
# 19450               Autonomous truck loader and unloader    B2  6318818
# 19464               Autonomous truck loader and unloader    B2  6318818
# 19487               Autonomous truck loader and unloader    B2  6318818
# 19496                           Robotic sortation system    B1  6177674
# 19497                 Collaborative inventory monitoring    B2   263891
#
#       citations references disruption edm_disruption
# 288        13.0       12.0  -0.010989       0.796320
# 291        40.0        7.0  -0.138462       0.862130
# 352        12.0       11.0  -0.019084       0.799165
# 385         4.0       12.0  -0.004484       1.064662
# 410        17.0       12.0  -0.010340       0.764071
# ...         ...        ...        ...            ...
# 19450       6.0       70.0  -0.006508       0.790221
# 19464       6.0       70.0  -0.006508       0.790221
# 19487       6.0       70.0  -0.006508       0.790221
# 19496       3.0        5.0  -0.005814       0.922881
# 19497       4.0       12.0  -0.004484       1.064662
#
# [536 rows x 29 columns]
